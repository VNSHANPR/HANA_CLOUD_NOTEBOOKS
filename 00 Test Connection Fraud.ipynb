# %% [markdown]
# # Fraud Classification - Test Connection to SAP HANA
# <BR><BR>The purpose of this notebook is to test the connection to HANA Cloud. And check the location of the data that will be used in the project.

# %% [markdown]
# ### Steps in this notebook
# -  Connect to HANA Cloud using hana_ml python package
# -  Check the location of the data
# -  Confirm that APL is installed
#
# ### Documentation
# -  SAP HANA Python Client API for Machine Learning Algorithms:
#    https://help.sap.com/doc/0172e3957b5946da85d3fde85ee8f33d/latest/en-US/html/hana_ml.html
# -  SAP HANA Predictive Analysis Library (PAL):
#    https://help.sap.com/viewer/319d36de4fd64ac3afbf91b1fb3ce8de/cloud/en-US
# -  SAP HANA Automated Predictive Library (APL):
#    https://help.sap.com/viewer/product/apl/2018/en-US

# %% [markdown]
# ### Connect to HANA Cloud
# Begin by checking if hana_ml package is installed.
#
# If not installed, use '!pip install hana_ml' to install the latest version of the package.

# %%
import hana_ml
print(hana_ml.__version__)
# Out:
# 2.5.20062609

# %% [markdown]
# Instantiate a connecton object to SAP HANA.
# -  For simplicity, to help you get started, the values can be hardcoded here.
# -  We recommend keeping these credentials in the Secure User Store of the SAP HANA Client. Retrieving the credentials from the Secure User Store prevents having to specify these credentials in clear text.
#
# To connect to a HANA Cloud instance, we need
# -  URL
# -  Port (usually 443)
# -  user and password OR hdbuserstore 'key'
# -  encrypt = 'true' to ensure that we use an encrypted connection

# %%
import hana_ml.dataframe as dataframe

# Instantiate connection object
# conn = dataframe.ConnectionContext(address = 'd1c353c3-ea74-4e9a-bda5-897d70fd7376.hana.prod-us10.hanacloud.ondemand.com',
#                                    port = 443, 
#                                    user = 'BIUSER', 
#                                    password = 'xxxx', 
#                                    encrypt = 'true'
#                                   )

# Stored in hdbuserstore on a Mac using the below statement (in /Applications/sap/hdbclient)
# hdbuserstore -i SET PRESALESHC "d1c353c3-ea74-4e9a-bda5-897d70fd7376.hana.prod-us10.hanacloud.ondemand.com:443" BIUSER
conn = dataframe.ConnectionContext(key = 'NA_POC_HANA_CLOUD', encrypt = 'true',sslValidateCertificate = 'false')

# %%
# Send basic SELECT statement and display the result
sql = 'SELECT 12345 FROM DUMMY'
df_remote = conn.sql(sql)
print(df_remote.collect())
# Out:
#    12345
# 0  12345

# %% [markdown]
# ### Check the location of the data
# For this project, all the data is stored in SOURCEDATA schema.

# %%
conn.sql("Select * from TABLES WHERE SCHEMA_NAME='SOURCEDATA'").collect()
# Out:
#    SCHEMA_NAME                      TABLE_NAME  TABLE_OID  \
# 0   SOURCEDATA                            CARD     165754
# 1   SOURCEDATA               CARD_TRANSACTIONS     165767
# 2   SOURCEDATA       CARD_TRANSACTIONS_HOTWARM     165781
# 3   SOURCEDATA                        CUSTOMER     165796
# 4   SOURCEDATA                        MERCHANT     165813
# 5   SOURCEDATA                     MERCHANT_CA     171144
# 6   SOURCEDATA          CARD_TRANSACTIONS_COLD     165825
# 7   SOURCEDATA                 EXCEL_Tax_20000     166282
# 8   SOURCEDATA                   SQLSERVER_Tag     166293
# 9   SOURCEDATA            VT_CARD_TRANSACTIONS     171504
# 10  SOURCEDATA             VT_CA_POWER_OUTAGES     172312
# 11  SOURCEDATA      VT_CA_WEATHER_SENSOR_DAILY     172374
# 12  SOURCEDATA  VT_CA_WEATHER_SENSOR_HOURLY_HC     171424
# 13  SOURCEDATA    VT_WEATHER_SENSOR_DATA_DAILY     175038
# 14  SOURCEDATA             VT_WEATHER_STATIONS     171158
#
#                                          COMMENTS  FIXED_PART_SIZE IS_LOGGED  \
# 0                                           Cards             48.0      TRUE
# 1      Card Transactions (full datsaet in-memory)             56.0      TRUE
# 2   Card Transactions hot & warm data (partition)             56.0      TRUE
# 3                                        Customer             72.0      TRUE
# 4                                        Merchant             56.0      TRUE
# 5                                            None             88.0      TRUE
# 6                                            None              NaN      TRUE
# 7                                            None              NaN      TRUE
# 8                                            None              NaN      TRUE
# 9                                            None              NaN      TRUE
# 10                                           None              NaN      TRUE
# 11                                           None              NaN      TRUE
# 12                                           None              NaN      TRUE
# 13                                           None              NaN      TRUE
# 14                                           None              NaN      TRUE
#
#    IS_SYSTEM_TABLE IS_COLUMN_TABLE TABLE_TYPE IS_INSERT_ONLY  ...  \
# 0            FALSE            TRUE     COLUMN          FALSE  ...
# 1            FALSE            TRUE     COLUMN          FALSE  ...
# 2            FALSE            TRUE     COLUMN          FALSE  ...
# 3            FALSE            TRUE     COLUMN          FALSE  ...
# 4            FALSE            TRUE     COLUMN          FALSE  ...
# 5            FALSE            TRUE     COLUMN          FALSE  ...
# 6            FALSE           FALSE    VIRTUAL           TRUE  ...
# 7            FALSE           FALSE    VIRTUAL           TRUE  ...
# 8            FALSE           FALSE    VIRTUAL           TRUE  ...
# 9            FALSE           FALSE    VIRTUAL           TRUE  ...
# 10           FALSE           FALSE    VIRTUAL           TRUE  ...
# 11           FALSE           FALSE    VIRTUAL           TRUE  ...
# 12           FALSE           FALSE    VIRTUAL           TRUE  ...
# 13           FALSE           FALSE    VIRTUAL           TRUE  ...
# 14           FALSE           FALSE    VIRTUAL           TRUE  ...
#
#    ROW_ORDER_TYPE             CREATE_TIME TEMPORAL_TYPE HAS_MASKED_COLUMNS  \
# 0            None 2020-08-15 23:33:28.660          None              FALSE
# 1            None 2020-08-15 23:33:28.681          None               TRUE
# 2            None 2020-08-15 23:33:28.700          None               TRUE
# 3            None 2020-08-15 23:33:28.720          None              FALSE
# 4            None 2020-08-15 23:33:28.737          None              FALSE
# 5            None 2020-08-26 13:34:46.053          None              FALSE
# 6            None 2020-08-15 23:35:36.808          None              FALSE
# 7            None 2020-08-17 20:17:36.429          None              FALSE
# 8            None 2020-08-18 20:28:43.593          None              FALSE
# 9            None 2020-08-28 15:58:23.429          None              FALSE
# 10           None 2020-09-03 18:27:50.092          None              FALSE
# 11           None 2020-09-03 20:50:11.540          None              FALSE
# 12           None 2020-08-28 15:51:08.085          None              FALSE
# 13           None 2020-09-08 01:46:54.629          None              FALSE
# 14           None 2020-08-26 14:20:51.797          None              FALSE
#
#    PERSISTENT_MEMORY HAS_RECORD_COMMIT_TIMESTAMP IS_REPLICATION_LOG_ENABLED  \
# 0               None                       FALSE                      FALSE
# 1               None                       FALSE                      FALSE
# 2               None                       FALSE                      FALSE
# 3               None                       FALSE                      FALSE
# 4               None                       FALSE                      FALSE
# 5               None                       FALSE                      FALSE
# 6               None                       FALSE                      FALSE
# 7               None                       FALSE                      FALSE
# 8               None                       FALSE                      FALSE
# 9               None                       FALSE                      FALSE
# 10              None                       FALSE                      FALSE
# 11              None                       FALSE                      FALSE
# 12              None                       FALSE                      FALSE
# 13              None                       FALSE                      FALSE
# 14              None                       FALSE                      FALSE
#
#    NUMA_NODE_INDEXES IS_MOVABLE LOAD_UNIT
# 0               None       TRUE    COLUMN
# 1               None       TRUE    COLUMN
# 2               None       TRUE   DEFAULT
# 3               None       TRUE    COLUMN
# 4               None       TRUE    COLUMN
# 5               None       TRUE   DEFAULT
# 6               None      FALSE   DEFAULT
# 7               None      FALSE   DEFAULT
# 8               None      FALSE   DEFAULT
# 9               None      FALSE   DEFAULT
# 10              None      FALSE   DEFAULT
# 11              None      FALSE   DEFAULT
# 12              None      FALSE   DEFAULT
# 13              None      FALSE   DEFAULT
# 14              None      FALSE   DEFAULT
#
# [15 rows x 38 columns]

# %% [markdown]
# ### Confirm that APL is installed
#
# When APL (Automated Predictive Library) has been installed on SAP HANA Cloud, there are several functions created under AREA_NAME (APL_AREA); and PACKAGE_NAME (APL) under SYS.AFL_FUNCTIONS.

# %%
conn.sql("select * from SYS.AFL_FUNCTIONS where AREA_NAME='APL_AREA'").collect()
# Out:
#     FUNCTION_OID SCHEMA_NAME AREA_NAME PACKAGE_NAME  \
# 0         156970    _SYS_AFL  APL_AREA          APL
# 1         156971    _SYS_AFL  APL_AREA          APL
# 2         156972    _SYS_AFL  APL_AREA          APL
# 3         156973    _SYS_AFL  APL_AREA          APL
# 4         156974    _SYS_AFL  APL_AREA          APL
# 5         156975    _SYS_AFL  APL_AREA          APL
# 6         156976    _SYS_AFL  APL_AREA          APL
# 7         156977    _SYS_AFL  APL_AREA          APL
# 8         156978    _SYS_AFL  APL_AREA          APL
# 9         156979    _SYS_AFL  APL_AREA          APL
# 10        156980    _SYS_AFL  APL_AREA          APL
# 11        156981    _SYS_AFL  APL_AREA          APL
# 12        156982    _SYS_AFL  APL_AREA          APL
# 13        156983    _SYS_AFL  APL_AREA          APL
# 14        156984    _SYS_AFL  APL_AREA          APL
# 15        156985    _SYS_AFL  APL_AREA          APL
# 16        156986    _SYS_AFL  APL_AREA          APL
# 17        156987    _SYS_AFL  APL_AREA          APL
# 18        156988    _SYS_AFL  APL_AREA          APL
# 19        156989    _SYS_AFL  APL_AREA          APL
# 20        156990    _SYS_AFL  APL_AREA          APL
# 21        156991    _SYS_AFL  APL_AREA          APL
# 22        156992    _SYS_AFL  APL_AREA          APL
# 23        156993    _SYS_AFL  APL_AREA          APL
# 24        156994    _SYS_AFL  APL_AREA          APL
# 25        156995    _SYS_AFL  APL_AREA          APL
# 26        156996    _SYS_AFL  APL_AREA          APL
# 27        156997    _SYS_AFL  APL_AREA          APL
# 28        156998    _SYS_AFL  APL_AREA          APL
# 29        156999    _SYS_AFL  APL_AREA          APL
# 30        157000    _SYS_AFL  APL_AREA          APL
# 31        157001    _SYS_AFL  APL_AREA          APL
# 32        157002    _SYS_AFL  APL_AREA          APL
# 33        157003    _SYS_AFL  APL_AREA          APL
# 34        157004    _SYS_AFL  APL_AREA          APL
# 35        157005    _SYS_AFL  APL_AREA          APL
# 36        157006    _SYS_AFL  APL_AREA          APL
# 37        157007    _SYS_AFL  APL_AREA          APL
# 38        157008    _SYS_AFL  APL_AREA          APL
# 39        157009    _SYS_AFL  APL_AREA          APL
# 40        157010    _SYS_AFL  APL_AREA          APL
# 41        157011    _SYS_AFL  APL_AREA          APL
# 42        157012    _SYS_AFL  APL_AREA          APL
# 43        157013    _SYS_AFL  APL_AREA          APL
# 44        157014    _SYS_AFL  APL_AREA          APL
# 45        157015    _SYS_AFL  APL_AREA          APL
# 46        157016    _SYS_AFL  APL_AREA          APL
# 47        157017    _SYS_AFL  APL_AREA          APL
# 48        157018    _SYS_AFL  APL_AREA          APL
# 49        157019    _SYS_AFL  APL_AREA          APL
# 50        157020    _SYS_AFL  APL_AREA          APL
# 51        157021    _SYS_AFL  APL_AREA          APL
# 52        157022    _SYS_AFL  APL_AREA          APL
# 53        157023    _SYS_AFL  APL_AREA          APL
#
#                                 FUNCTION_NAME        CREATE_TIMESTAMP  \
# 0                                CREATE_MODEL 2020-07-19 04:27:28.559
# 1                  CREATE_MODEL__OVERLOAD_3_1 2020-07-19 04:27:28.563
# 2                 IMPORT_VARIABLEDESCRIPTIONS 2020-07-19 04:27:28.567
# 3                 EXPORT_VARIABLEDESCRIPTIONS 2020-07-19 04:27:28.570
# 4                      CREATE_MODEL_AND_TRAIN 2020-07-19 04:27:28.573
# 5        CREATE_MODEL_AND_TRAIN__OVERLOAD_5_1 2020-07-19 04:27:28.578
# 6        CREATE_MODEL_AND_TRAIN__OVERLOAD_7_1 2020-07-19 04:27:28.582
# 7        CREATE_MODEL_AND_TRAIN__OVERLOAD_7_4 2020-07-19 04:27:28.586
# 8                                 TRAIN_MODEL 2020-07-19 04:27:28.590
# 9                   TRAIN_MODEL__OVERLOAD_5_1 2020-07-19 04:27:28.594
# 10                  TRAIN_MODEL__OVERLOAD_7_1 2020-07-19 04:27:28.598
# 11                  TRAIN_MODEL__OVERLOAD_7_4 2020-07-19 04:27:28.603
# 12                              RETRAIN_MODEL 2020-07-19 04:27:28.609
# 13                RETRAIN_MODEL__OVERLOAD_6_4 2020-07-19 04:27:28.614
# 14                   GET_TABLE_TYPE_FOR_APPLY 2020-07-19 04:27:28.620
# 15                                APPLY_MODEL 2020-07-19 04:27:28.624
# 16                  APPLY_MODEL__OVERLOAD_4_3 2020-07-19 04:27:28.628
# 17                  APPLY_MODEL__OVERLOAD_4_1 2020-07-19 04:27:28.633
# 18                       PARALLEL_APPLY_MODEL 2020-07-19 04:27:28.637
# 19                                 TEST_MODEL 2020-07-19 04:27:28.642
# 20                       APPLY_MODEL_AND_TEST 2020-07-19 04:27:28.647
# 21                    GET_VARIABLE_INDICATORS 2020-07-19 04:27:28.652
# 22                        EXPORT_PROFITCURVES 2020-07-19 04:27:28.655
# 23                          EXPORT_APPLY_CODE 2020-07-19 04:27:28.659
# 24                              PUBLISH_MODEL 2020-07-19 04:27:28.662
# 25                               UPDATE_MODEL 2020-07-19 04:27:28.666
# 26                          GET_MODEL_DEBRIEF 2020-07-19 04:27:28.670
# 27                             GET_MODEL_INFO 2020-07-19 04:27:28.674
# 28               GET_MODEL_INFO__OVERLOAD_3_6 2020-07-19 04:27:28.678
# 29                    GET_MODEL_DATASET_TYPES 2020-07-19 04:27:28.682
# 30                CREATE_RECO_MODEL_AND_TRAIN 2020-07-19 04:27:28.686
# 31  CREATE_RECO_MODEL_AND_TRAIN__OVERLOAD_4_8 2020-07-19 04:27:28.691
# 32                           APPLY_RECO_MODEL 2020-07-19 04:27:28.696
# 33                  PARALLEL_APPLY_RECO_MODEL 2020-07-19 04:27:28.701
# 34                 EXPORT_APPLY_CODE_FOR_RECO 2020-07-19 04:27:28.706
# 35              CREATE_SOCIAL_MODEL_AND_TRAIN 2020-07-19 04:27:28.712
# 36            GET_TABLE_TYPE_FOR_SOCIAL_APPLY 2020-07-19 04:27:28.720
# 37                         APPLY_SOCIAL_MODEL 2020-07-19 04:27:28.726
# 38                PARALLEL_APPLY_SOCIAL_MODEL 2020-07-19 04:27:28.733
# 39                                   FORECAST 2020-07-19 04:27:28.739
# 40                     FORECAST__OVERLOAD_5_1 2020-07-19 04:27:28.744
# 41                     FORECAST__OVERLOAD_5_6 2020-07-19 04:27:28.748
# 42                            KEY_INFLUENCERS 2020-07-19 04:27:28.754
# 43             GET_KEY_INFLUENCERS_FROM_MODEL 2020-07-19 04:27:28.759
# 44                           SCORING_EQUATION 2020-07-19 04:27:28.764
# 45             SCORING_EQUATION__OVERLOAD_5_5 2020-07-19 04:27:28.769
# 46                                  RECOMMEND 2020-07-19 04:27:28.774
# 47                    RECOMMEND__OVERLOAD_5_1 2020-07-19 04:27:28.778
# 48                               PROFILE_DATA 2020-07-19 04:27:28.783
# 49      PROFILE_DATA_AND_GET_ASSOCIATIONRULES 2020-07-19 04:27:28.787
# 50                       DEBRIEF_APPLY_RESULT 2020-07-19 04:27:28.793
# 51                                  CONFIGURE 2020-07-19 04:27:28.798
# 52                                       PING 2020-07-19 04:27:28.801
# 53                           PROGRESS_CLEANUP 2020-07-19 04:27:28.805
#
#     INPUT_PARAMETER_COUNT  RETURN_VALUE_COUNT FUNCTION_TYPE TECHNICAL_CATEGORY
# 0                       3                   2         LFunc        var_columns
# 1                       3                   1         LFunc        var_columns
# 2                       3                   1         LFunc        var_columns
# 3                       2                   1         LFunc        var_columns
# 4                       5                   4         LFunc        var_columns
# 5                       5                   1         LFunc        var_columns
# 6                       7                   1         LFunc        var_columns
# 7                       7                   4         LFunc        var_columns
# 8                       5                   4         LFunc        var_columns
# 9                       5                   1         LFunc        var_columns
# 10                      7                   1         LFunc        var_columns
# 11                      7                   4         LFunc        var_columns
# 12                      4                   4         LFunc        var_columns
# 13                      6                   4         LFunc        var_columns
# 14                      4                   2         LFunc        var_columns
# 15                      4                   2         LFunc        var_columns
# 16                      4                   3         LFunc        var_columns
# 17                      4                   1         LFunc        var_columns
# 18                      4                   1         LFunc        var_columns
# 19                      4                   3         LFunc        var_columns
# 20                      4                   4         LFunc        var_columns
# 21                      3                   1         LFunc        var_columns
# 22                      3                   1         LFunc        var_columns
# 23                      3                   1         LFunc        var_columns
# 24                      4                   3         LFunc        var_columns
# 25                      3                   1         LFunc        var_columns
# 26                      3                   3         LFunc        var_columns
# 27                      3                   5         LFunc        var_columns
# 28                      3                   6         LFunc        var_columns
# 29                      3                   1         LFunc        var_columns
# 30                      4                   7         LFunc        var_columns
# 31                      4                   8         LFunc        var_columns
# 32                      7                   2         LFunc        var_columns
# 33                      7                   1         LFunc        var_columns
# 34                      6                   1         LFunc        var_columns
# 35                      7                  10         LFunc        var_columns
# 36                     10                   2         LFunc        var_columns
# 37                     10                   2         LFunc        var_columns
# 38                     10                   1         LFunc        var_columns
# 39                      5                   4         LFunc        var_columns
# 40                      5                   1         LFunc        var_columns
# 41                      5                   6         LFunc        var_columns
# 42                      5                   6         LFunc        var_columns
# 43                      3                   5         LFunc        var_columns
# 44                      5                   4         LFunc        var_columns
# 45                      5                   5         LFunc        var_columns
# 46                      5                   4         LFunc        var_columns
# 47                      5                   1         LFunc        var_columns
# 48                      5                   4         LFunc        var_columns
# 49                      5                   6         LFunc        var_columns
# 50                      7                   4         LFunc        var_columns
# 51                      1                   1         LFunc           var_none
# 52                      0                   1         LFunc           var_none
# 53                      1                   1         LFunc           var_none

# %% [markdown]
# Once preparation steps are done, we can close the connection to HANA Cloud. Continue with the next notebook, "05 Introduction".

# %%
conn.close()
